# %% [markdown]
# <a href="https://colab.research.google.com/github/cartmarsh/DataAnalysis/blob/main/HumanProteinAtlasDetection_4_Channel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
os.environ["KAGGLE_CONFIG_DIR"] = "/content"

# %%
# !kaggle competitions download -c human-protein-atlas-image-classification
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading human-protein-atlas-image-classification.zip to /content
# 100% 17.5G/17.5G [09:39<00:00, 36.7MB/s]
# 100% 17.5G/17.5G [09:39<00:00, 32.4MB/s]

# %%
# !unzip human-protein-atlas-image-classification.zip
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: train/f5b629aa-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5b629aa-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5b629aa-bbbb-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5b629aa-bbbb-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5b6f5c0-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5b6f5c0-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5b6f5c0-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5b6f5c0-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5baae8e-bbc1-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f5baae8e-bbc1-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f5baae8e-bbc1-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f5baae8e-bbc1-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f5c09c38-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5c09c38-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5c09c38-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5c09c38-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5c160fe-bbb1-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5c160fe-bbb1-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5c160fe-bbb1-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5c160fe-bbb1-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5c2885e-bb9c-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f5c2885e-bb9c-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f5c2885e-bb9c-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f5c2885e-bb9c-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f5c6397a-bb99-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f5c6397a-bb99-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f5c6397a-bb99-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f5c6397a-bb99-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f5c6720c-bbba-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5c6720c-bbba-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5c6720c-bbba-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5c6720c-bbba-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5cabd4a-bba0-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f5cabd4a-bba0-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f5cabd4a-bba0-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f5cabd4a-bba0-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f5cb5896-bba9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5cb5896-bba9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5cb5896-bba9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5cb5896-bba9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5cba356-bba8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5cba356-bba8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5cba356-bba8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5cba356-bba8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5cbc37e-bb9c-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f5cbc37e-bb9c-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f5cbc37e-bb9c-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f5cbc37e-bb9c-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f5cca6e0-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5cca6e0-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5cca6e0-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5cca6e0-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5ccb30e-bbc6-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5ccb30e-bbc6-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5ccb30e-bbc6-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5ccb30e-bbc6-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5ccb3b2-bba4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5ccb3b2-bba4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5ccb3b2-bba4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5ccb3b2-bba4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5cf3564-bbc8-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5cf3564-bbc8-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5cf3564-bbc8-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5cf3564-bbc8-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5cf8f90-bbc9-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5cf8f90-bbc9-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5cf8f90-bbc9-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5cf8f90-bbc9-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5d5eb58-bba4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5d5eb58-bba4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5d5eb58-bba4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5d5eb58-bba4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5dad562-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5dad562-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5dad562-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5dad562-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5dcef62-bbb2-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5dcef62-bbb2-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5dcef62-bbb2-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5dcef62-bbb2-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5dd5158-bbbe-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5dd5158-bbbe-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5dd5158-bbbe-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5dd5158-bbbe-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5de51fa-bbac-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5de51fa-bbac-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5de51fa-bbac-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5de51fa-bbac-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5df678a-bbc9-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5df678a-bbc9-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5df678a-bbc9-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5df678a-bbc9-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5e0bf70-bbad-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5e0bf70-bbad-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5e0bf70-bbad-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5e0bf70-bbad-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5e495ea-bbbd-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5e495ea-bbbd-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5e495ea-bbbd-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5e495ea-bbbd-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5e62b60-bbbf-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f5e62b60-bbbf-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f5e62b60-bbbf-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f5e62b60-bbbf-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f5e82cde-bbb6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5e82cde-bbb6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5e82cde-bbb6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5e82cde-bbb6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5e87f28-bbc9-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5e87f28-bbc9-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5e87f28-bbc9-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5e87f28-bbc9-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5e998f2-bba3-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f5e998f2-bba3-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f5e998f2-bba3-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f5e998f2-bba3-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f5edd364-bbc0-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f5edd364-bbc0-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f5edd364-bbc0-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f5edd364-bbc0-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f5efe4fc-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f5efe4fc-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f5efe4fc-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f5efe4fc-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f5f0768e-bbb9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5f0768e-bbb9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5f0768e-bbb9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5f0768e-bbb9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5f09afa-bbb5-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5f09afa-bbb5-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5f09afa-bbb5-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5f09afa-bbb5-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5f169ae-bbaa-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5f169ae-bbaa-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5f169ae-bbaa-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5f169ae-bbaa-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5fbd262-bbab-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5fbd262-bbab-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5fbd262-bbab-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5fbd262-bbab-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5fd654e-bba8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5fd654e-bba8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5fd654e-bba8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5fd654e-bba8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5fe5b4a-bbb0-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5fe5b4a-bbb0-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5fe5b4a-bbb0-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5fe5b4a-bbb0-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5fee39c-bbc1-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f5fee39c-bbc1-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f5fee39c-bbc1-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f5fee39c-bbc1-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f5ff171e-bbac-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5ff171e-bbac-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5ff171e-bbac-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5ff171e-bbac-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5ff4106-bba4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f5ff4106-bba4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f5ff4106-bba4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f5ff4106-bba4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f5ffe100-bb9b-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f5ffe100-bb9b-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f5ffe100-bb9b-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f5ffe100-bb9b-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f605bdfe-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f605bdfe-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f605bdfe-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f605bdfe-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f606b43a-bbb4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f606b43a-bbb4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f606b43a-bbb4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f606b43a-bbb4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f608ccda-bbae-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f608ccda-bbae-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f608ccda-bbae-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f608ccda-bbae-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f609c3ee-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f609c3ee-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f609c3ee-bbbb-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f609c3ee-bbbb-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f60a1516-bba1-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f60a1516-bba1-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f60a1516-bba1-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f60a1516-bba1-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f60ad1ee-bbac-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f60ad1ee-bbac-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f60ad1ee-bbac-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f60ad1ee-bbac-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f60c8456-bbb8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f60c8456-bbb8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f60c8456-bbb8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f60c8456-bbb8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f60d8480-bbab-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f60d8480-bbab-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f60d8480-bbab-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f60d8480-bbab-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f60fe09a-bbc9-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f60fe09a-bbc9-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f60fe09a-bbc9-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f60fe09a-bbc9-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6118d2a-bbbd-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6118d2a-bbbd-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6118d2a-bbbd-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6118d2a-bbbd-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6123226-bbc6-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6123226-bbc6-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6123226-bbc6-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6123226-bbc6-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f612a65c-bbad-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f612a65c-bbad-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f612a65c-bbad-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f612a65c-bbad-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6145a2e-bba8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6145a2e-bba8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6145a2e-bba8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6145a2e-bba8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f615ee5c-bbad-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f615ee5c-bbad-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f615ee5c-bbad-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f615ee5c-bbad-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f619c46c-bbaa-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f619c46c-bbaa-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f619c46c-bbaa-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f619c46c-bbaa-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f619e538-bbb8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f619e538-bbb8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f619e538-bbb8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f619e538-bbb8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f61e2b24-bbaa-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f61e2b24-bbaa-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f61e2b24-bbaa-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f61e2b24-bbaa-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6208d02-bba9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6208d02-bba9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6208d02-bba9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6208d02-bba9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f62201d2-bbae-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f62201d2-bbae-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f62201d2-bbae-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f62201d2-bbae-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f623be3e-bbb1-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f623be3e-bbb1-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f623be3e-bbb1-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f623be3e-bbb1-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f624c4ca-bbc3-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f624c4ca-bbc3-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f624c4ca-bbc3-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f624c4ca-bbc3-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6265d48-bbba-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6265d48-bbba-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6265d48-bbba-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6265d48-bbba-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f627ad0a-bbc5-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f627ad0a-bbc5-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f627ad0a-bbc5-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f627ad0a-bbc5-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f62832b8-bbaf-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f62832b8-bbaf-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f62832b8-bbaf-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f62832b8-bbaf-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6285784-bbaf-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6285784-bbaf-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6285784-bbaf-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6285784-bbaf-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6291124-bbc3-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6291124-bbc3-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6291124-bbc3-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6291124-bbc3-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f629be72-bbb3-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f629be72-bbb3-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f629be72-bbb3-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f629be72-bbb3-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f62e3cc0-bba1-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f62e3cc0-bba1-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f62e3cc0-bba1-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f62e3cc0-bba1-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f630af46-bbbf-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f630af46-bbbf-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f630af46-bbbf-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f630af46-bbbf-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f630c696-bb99-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f630c696-bb99-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f630c696-bb99-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f630c696-bb99-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f633b1e0-bbac-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f633b1e0-bbac-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f633b1e0-bbac-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f633b1e0-bbac-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6374af2-bbbc-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6374af2-bbbc-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6374af2-bbbc-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6374af2-bbbc-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f637a6e4-bba0-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f637a6e4-bba0-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f637a6e4-bba0-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f637a6e4-bba0-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f63df1ec-bba1-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f63df1ec-bba1-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f63df1ec-bba1-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f63df1ec-bba1-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f63f12b4-bbb7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f63f12b4-bbb7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f63f12b4-bbb7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f63f12b4-bbb7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f640b4d4-bb99-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f640b4d4-bb99-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f640b4d4-bb99-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f640b4d4-bb99-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f643530c-bba2-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f643530c-bba2-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f643530c-bba2-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f643530c-bba2-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6448db0-bbbd-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6448db0-bbbd-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6448db0-bbbd-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6448db0-bbbd-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f649aec6-bbb8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f649aec6-bbb8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f649aec6-bbb8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f649aec6-bbb8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6542f20-bba6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6542f20-bba6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6542f20-bba6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6542f20-bba6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6577b6e-bb9f-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6577b6e-bb9f-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6577b6e-bb9f-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6577b6e-bb9f-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f658bf46-bbc3-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f658bf46-bbc3-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f658bf46-bbc3-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f658bf46-bbc3-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f659b9b2-bba2-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f659b9b2-bba2-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f659b9b2-bba2-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f659b9b2-bba2-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f65bfe6c-bbba-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f65bfe6c-bbba-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f65bfe6c-bbba-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f65bfe6c-bbba-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f65dedea-bba0-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f65dedea-bba0-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f65dedea-bba0-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f65dedea-bba0-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f65fd890-bb9a-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f65fd890-bb9a-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f65fd890-bb9a-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f65fd890-bb9a-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6605930-bba6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6605930-bba6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6605930-bba6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6605930-bba6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6619b52-bbc3-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6619b52-bbc3-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6619b52-bbc3-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6619b52-bbc3-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6625faa-bbb5-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6625faa-bbb5-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6625faa-bbb5-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6625faa-bbb5-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6627258-bbae-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6627258-bbae-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6627258-bbae-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6627258-bbae-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f663fdb4-bba7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f663fdb4-bba7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f663fdb4-bba7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f663fdb4-bba7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6647c50-bba5-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6647c50-bba5-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6647c50-bba5-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6647c50-bba5-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f66629e0-bbb6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f66629e0-bbb6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f66629e0-bbb6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f66629e0-bbb6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6667422-bba7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6667422-bba7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6667422-bba7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6667422-bba7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f667c53e-bbc0-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f667c53e-bbc0-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f667c53e-bbc0-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f667c53e-bbc0-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f668f9ec-bbc8-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f668f9ec-bbc8-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f668f9ec-bbc8-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f668f9ec-bbc8-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f66eb58e-bbc9-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f66eb58e-bbc9-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f66eb58e-bbc9-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f66eb58e-bbc9-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f66fae2a-bbc0-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f66fae2a-bbc0-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f66fae2a-bbc0-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f66fae2a-bbc0-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f6737566-bbaa-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6737566-bbaa-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6737566-bbaa-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6737566-bbaa-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6767ce2-bbab-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6767ce2-bbab-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6767ce2-bbab-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6767ce2-bbab-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f678b356-bba9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f678b356-bba9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f678b356-bba9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f678b356-bba9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f67cd814-bbb3-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f67cd814-bbb3-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f67cd814-bbb3-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f67cd814-bbb3-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f67dd78e-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f67dd78e-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f67dd78e-bbbb-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f67dd78e-bbbb-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f67e7ce0-bbb4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f67e7ce0-bbb4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f67e7ce0-bbb4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f67e7ce0-bbb4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f67f532a-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f67f532a-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f67f532a-bbbb-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f67f532a-bbbb-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6818aee-bb9a-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6818aee-bb9a-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6818aee-bb9a-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6818aee-bb9a-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6823a8e-bba9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6823a8e-bba9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6823a8e-bba9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6823a8e-bba9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f684a63e-bb9f-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f684a63e-bb9f-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f684a63e-bb9f-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f684a63e-bb9f-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f68566b8-bbb4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f68566b8-bbb4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f68566b8-bbb4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f68566b8-bbb4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f68654c2-bbb6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f68654c2-bbb6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f68654c2-bbb6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f68654c2-bbb6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f689729a-bba4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f689729a-bba4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f689729a-bba4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f689729a-bba4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f68c7988-bba2-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f68c7988-bba2-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f68c7988-bba2-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f68c7988-bba2-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f69226f2-bbbc-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f69226f2-bbbc-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f69226f2-bbbc-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f69226f2-bbbc-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f698c89e-bbae-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f698c89e-bbae-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f698c89e-bbae-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f698c89e-bbae-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f69bdc72-bba0-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f69bdc72-bba0-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f69bdc72-bba0-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f69bdc72-bba0-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f69ca1ee-bbc7-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f69ca1ee-bbc7-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f69ca1ee-bbc7-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f69ca1ee-bbc7-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6a55962-bbb1-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6a55962-bbb1-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6a55962-bbb1-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6a55962-bbb1-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6a8e7dc-bbc3-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6a8e7dc-bbc3-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6a8e7dc-bbc3-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6a8e7dc-bbc3-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6a96e14-bbc8-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6a96e14-bbc8-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6a96e14-bbc8-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6a96e14-bbc8-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6a9ebcc-bbb5-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6a9ebcc-bbb5-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6a9ebcc-bbb5-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6a9ebcc-bbb5-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6ad00c6-bbc1-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f6ad00c6-bbc1-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f6ad00c6-bbc1-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f6ad00c6-bbc1-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f6ad2d6c-bba3-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6ad2d6c-bba3-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6ad2d6c-bba3-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6ad2d6c-bba3-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6b064be-bbc6-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6b064be-bbc6-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6b064be-bbc6-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6b064be-bbc6-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6b23780-bbbc-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6b23780-bbbc-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6b23780-bbbc-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6b23780-bbbc-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6b419fc-bbb6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6b419fc-bbb6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6b419fc-bbb6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6b419fc-bbb6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6b61b26-bbb6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6b61b26-bbb6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6b61b26-bbb6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6b61b26-bbb6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6b8b06a-bb99-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6b8b06a-bb99-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6b8b06a-bb99-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6b8b06a-bb99-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6ba9fc6-bbb5-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6ba9fc6-bbb5-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6ba9fc6-bbb5-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6ba9fc6-bbb5-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6bcf188-bbb3-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6bcf188-bbb3-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6bcf188-bbb3-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6bcf188-bbb3-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6bed276-bbb0-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6bed276-bbb0-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6bed276-bbb0-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6bed276-bbb0-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6c05dc4-bbc1-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f6c05dc4-bbc1-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f6c05dc4-bbc1-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f6c05dc4-bbc1-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f6c27c72-bbc5-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6c27c72-bbc5-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6c27c72-bbc5-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6c27c72-bbc5-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6c54a82-bb9e-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6c54a82-bb9e-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6c54a82-bb9e-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6c54a82-bb9e-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6c65dda-bbbe-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6c65dda-bbbe-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6c65dda-bbbe-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6c65dda-bbbe-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6c67a4e-bbbf-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f6c67a4e-bbbf-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f6c67a4e-bbbf-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f6c67a4e-bbbf-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f6c79764-bba4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6c79764-bba4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6c79764-bba4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6c79764-bba4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6cad70a-bba7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6cad70a-bba7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6cad70a-bba7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6cad70a-bba7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6cd5eda-bba2-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6cd5eda-bba2-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6cd5eda-bba2-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6cd5eda-bba2-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6cefc98-bbae-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6cefc98-bbae-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6cefc98-bbae-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6cefc98-bbae-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6d23664-bbb9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6d23664-bbb9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6d23664-bbb9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6d23664-bbb9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6d88fc4-bbc2-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6d88fc4-bbc2-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6d88fc4-bbc2-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6d88fc4-bbc2-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6d8fab8-bba4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6d8fab8-bba4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6d8fab8-bba4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6d8fab8-bba4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6dc9104-bbb9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6dc9104-bbb9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6dc9104-bbb9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6dc9104-bbb9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6dc9f94-bba7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6dc9f94-bba7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6dc9f94-bba7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6dc9f94-bba7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6defda6-bbb7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6defda6-bbb7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6defda6-bbb7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6defda6-bbb7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6e17e3e-bba6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6e17e3e-bba6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6e17e3e-bba6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6e17e3e-bba6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6e1ba12-bb9b-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6e1ba12-bb9b-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6e1ba12-bb9b-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6e1ba12-bb9b-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6e40380-bbaf-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6e40380-bbaf-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6e40380-bbaf-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6e40380-bbaf-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6e49216-bbb7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6e49216-bbb7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6e49216-bbb7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6e49216-bbb7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6e5d632-bba1-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6e5d632-bba1-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6e5d632-bba1-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6e5d632-bba1-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6e7b42a-bbb0-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6e7b42a-bbb0-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6e7b42a-bbb0-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6e7b42a-bbb0-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6e7f58e-bba6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6e7f58e-bba6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6e7f58e-bba6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6e7f58e-bba6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6e90044-bbc1-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f6e90044-bbc1-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f6e90044-bbc1-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f6e90044-bbc1-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f6ec82aa-bba3-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6ec82aa-bba3-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6ec82aa-bba3-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6ec82aa-bba3-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6edbcc2-bbc8-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6edbcc2-bbc8-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6edbcc2-bbc8-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6edbcc2-bbc8-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6ee8848-bbad-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6ee8848-bbad-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6ee8848-bbad-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6ee8848-bbad-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6f2068a-bba3-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f6f2068a-bba3-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f6f2068a-bba3-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f6f2068a-bba3-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f6f5ea16-bbc6-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f6f5ea16-bbc6-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f6f5ea16-bbc6-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f6f5ea16-bbc6-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f6f91212-bbbd-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6f91212-bbbd-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6f91212-bbbd-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6f91212-bbbd-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f6ff8720-bbb6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f6ff8720-bbb6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f6ff8720-bbb6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f6ff8720-bbb6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f7014dbe-bbbe-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f7014dbe-bbbe-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f7014dbe-bbbe-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f7014dbe-bbbe-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f7018418-bbba-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f7018418-bbba-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f7018418-bbba-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f7018418-bbba-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f702cb66-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f702cb66-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f702cb66-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f702cb66-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f7035070-bbc1-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f7035070-bbc1-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f7035070-bbc1-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f7035070-bbc1-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f704cef8-bbaf-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f704cef8-bbaf-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f704cef8-bbaf-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f704cef8-bbaf-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f7091a9e-bbb9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f7091a9e-bbb9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f7091a9e-bbb9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f7091a9e-bbb9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f70cc9c4-bbc7-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f70cc9c4-bbc7-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f70cc9c4-bbc7-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f70cc9c4-bbc7-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f712bc1a-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f712bc1a-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f712bc1a-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f712bc1a-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f71598e6-bba0-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f71598e6-bba0-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f71598e6-bba0-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f71598e6-bba0-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f71758f4-bbb7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f71758f4-bbb7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f71758f4-bbb7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f71758f4-bbb7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f7186b9c-bbbf-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/f7186b9c-bbbf-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/f7186b9c-bbbf-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/f7186b9c-bbbf-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/f71b0de4-bbaf-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f71b0de4-bbaf-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f71b0de4-bbaf-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f71b0de4-bbaf-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f71d948a-bba8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f71d948a-bba8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f71d948a-bba8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f71d948a-bba8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f71da978-bbb4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f71da978-bbb4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/f71da978-bbb4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/f71da978-bbb4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/f71dc1c8-bb9c-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/f71dc1c8-bb9c-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/f71dc1c8-bb9c-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/f71dc1c8-bb9c-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/f71fc0bc-bbc5-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/f71fc0bc-bbc5-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/f71fc0bc-bbc5-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/f71fc0bc-bbc5-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/f7211944-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/f7211944-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
# ...
#   inflating: train/ff571e6c-bbaf-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff593c70-bb9a-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff593c70-bb9a-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff593c70-bb9a-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff593c70-bb9a-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff59f2f0-bb9a-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff59f2f0-bb9a-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff59f2f0-bb9a-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff59f2f0-bb9a-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff625c52-bbc6-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/ff625c52-bbc6-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/ff625c52-bbc6-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/ff625c52-bbc6-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/ff640c94-bba0-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff640c94-bba0-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff640c94-bba0-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff640c94-bba0-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff66fdbe-bbaa-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff66fdbe-bbaa-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff66fdbe-bbaa-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff66fdbe-bbaa-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff692f96-bb99-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff692f96-bb99-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff692f96-bb99-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff692f96-bb99-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff70c14a-bba1-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff70c14a-bba1-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff70c14a-bba1-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff70c14a-bba1-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff71ef92-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff71ef92-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff71ef92-bbbb-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff71ef92-bbbb-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff809516-bbba-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff809516-bbba-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff809516-bbba-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff809516-bbba-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff845e48-bbb1-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff845e48-bbb1-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff845e48-bbb1-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff845e48-bbb1-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff84765e-bba6-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff84765e-bba6-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff84765e-bba6-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff84765e-bba6-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff851e82-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff851e82-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff851e82-bbbb-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff851e82-bbbb-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff882fde-bb9b-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff882fde-bb9b-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff882fde-bb9b-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff882fde-bb9b-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff8a089a-bbb4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff8a089a-bbb4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff8a089a-bbb4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff8a089a-bbb4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff8a6ea6-bbba-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff8a6ea6-bbba-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff8a6ea6-bbba-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff8a6ea6-bbba-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff8b9096-bb9d-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff8b9096-bb9d-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff8b9096-bb9d-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff8b9096-bb9d-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff8dd0d0-bbad-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff8dd0d0-bbad-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff8dd0d0-bbad-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff8dd0d0-bbad-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff8e5cf2-bb9f-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff8e5cf2-bb9f-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff8e5cf2-bb9f-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff8e5cf2-bb9f-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff8ebd3a-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/ff8ebd3a-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/ff8ebd3a-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/ff8ebd3a-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/ff917b50-bbac-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff917b50-bbac-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff917b50-bbac-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff917b50-bbac-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff98ee96-bbb4-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff98ee96-bbb4-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff98ee96-bbb4-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff98ee96-bbb4-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff9a7f02-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ff9a7f02-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ff9a7f02-bbbb-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ff9a7f02-bbbb-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ff9aed56-bb9e-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ff9aed56-bb9e-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ff9aed56-bb9e-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ff9aed56-bb9e-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ff9f759e-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/ff9f759e-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/ff9f759e-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/ff9f759e-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/ffa2ad3a-bba7-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffa2ad3a-bba7-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffa2ad3a-bba7-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffa2ad3a-bba7-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffa65b3c-bba8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffa65b3c-bba8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffa65b3c-bba8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffa65b3c-bba8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffa9f2c2-bbaa-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffa9f2c2-bbaa-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffa9f2c2-bbaa-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffa9f2c2-bbaa-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffaa8068-bbad-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffaa8068-bbad-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffaa8068-bbad-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffaa8068-bbad-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffaebd74-bb9c-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ffaebd74-bb9c-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ffaebd74-bb9c-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ffaebd74-bb9c-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ffb00d58-bba3-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ffb00d58-bba3-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ffb00d58-bba3-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ffb00d58-bba3-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ffb49f82-bbab-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffb49f82-bbab-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffb49f82-bbab-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffb49f82-bbab-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffb5effa-bbaf-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffb5effa-bbaf-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffb5effa-bbaf-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffb5effa-bbaf-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffb610c6-bbb8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffb610c6-bbb8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffb610c6-bbb8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffb610c6-bbb8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffb6fb76-bba9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffb6fb76-bba9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffb6fb76-bba9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffb6fb76-bba9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffb74ef0-bbae-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffb74ef0-bbae-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffb74ef0-bbae-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffb74ef0-bbae-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffbebc4e-bb9a-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ffbebc4e-bb9a-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ffbebc4e-bb9a-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ffbebc4e-bb9a-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ffc30612-bbbf-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/ffc30612-bbbf-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/ffc30612-bbbf-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/ffc30612-bbbf-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/ffc8820a-bbc8-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/ffc8820a-bbc8-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/ffc8820a-bbc8-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/ffc8820a-bbc8-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/ffcebbc8-bbc5-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/ffcebbc8-bbc5-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/ffcebbc8-bbc5-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/ffcebbc8-bbc5-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/ffced1a2-bbad-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffced1a2-bbad-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffced1a2-bbad-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffced1a2-bbad-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffcf84d6-bbac-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffcf84d6-bbac-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffcf84d6-bbac-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffcf84d6-bbac-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffd23be4-bba3-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ffd23be4-bba3-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ffd23be4-bba3-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ffd23be4-bba3-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ffd298f4-bbc7-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/ffd298f4-bbc7-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/ffd298f4-bbc7-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/ffd298f4-bbc7-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/ffd2b880-bba8-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffd2b880-bba8-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffd2b880-bba8-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffd2b880-bba8-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffd45d0c-bbad-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffd45d0c-bbad-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffd45d0c-bbad-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffd45d0c-bbad-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffd96262-bbc0-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/ffd96262-bbc0-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/ffd96262-bbc0-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/ffd96262-bbc0-11e8-b2bb-ac1f6b6435d0_yellow.png
#   inflating: train/ffdb9014-bba2-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ffdb9014-bba2-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ffdb9014-bba2-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ffdb9014-bba2-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ffdbe064-bbbb-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffdbe064-bbbb-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffdbe064-bbbb-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffdbe064-bbbb-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffdcc5e4-bbaa-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffdcc5e4-bbaa-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffdcc5e4-bbaa-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffdcc5e4-bbaa-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffe454e6-bb99-11e8-b2b9-ac1f6b6435d0_blue.png
#   inflating: train/ffe454e6-bb99-11e8-b2b9-ac1f6b6435d0_green.png
#   inflating: train/ffe454e6-bb99-11e8-b2b9-ac1f6b6435d0_red.png
#   inflating: train/ffe454e6-bb99-11e8-b2b9-ac1f6b6435d0_yellow.png
#   inflating: train/ffe55eba-bbba-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffe55eba-bbba-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffe55eba-bbba-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffe55eba-bbba-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffe61798-bbc3-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/ffe61798-bbc3-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/ffe61798-bbc3-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/ffe61798-bbc3-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/ffe8cf0c-bba9-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffe8cf0c-bba9-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffe8cf0c-bba9-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffe8cf0c-bba9-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/ffeae6f0-bbc9-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/ffeae6f0-bbc9-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/ffeae6f0-bbc9-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/ffeae6f0-bbc9-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/ffed4430-bbac-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/ffed4430-bbac-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/ffed4430-bbac-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/ffed4430-bbac-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/fff0a998-bbae-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/fff0a998-bbae-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/fff0a998-bbae-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/fff0a998-bbae-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/fff189d8-bbab-11e8-b2ba-ac1f6b6435d0_blue.png
#   inflating: train/fff189d8-bbab-11e8-b2ba-ac1f6b6435d0_green.png
#   inflating: train/fff189d8-bbab-11e8-b2ba-ac1f6b6435d0_red.png
#   inflating: train/fff189d8-bbab-11e8-b2ba-ac1f6b6435d0_yellow.png
#   inflating: train/fffdf7e0-bbc4-11e8-b2bc-ac1f6b6435d0_blue.png
#   inflating: train/fffdf7e0-bbc4-11e8-b2bc-ac1f6b6435d0_green.png
#   inflating: train/fffdf7e0-bbc4-11e8-b2bc-ac1f6b6435d0_red.png
#   inflating: train/fffdf7e0-bbc4-11e8-b2bc-ac1f6b6435d0_yellow.png
#   inflating: train/fffe0ffe-bbc0-11e8-b2bb-ac1f6b6435d0_blue.png
#   inflating: train/fffe0ffe-bbc0-11e8-b2bb-ac1f6b6435d0_green.png
#   inflating: train/fffe0ffe-bbc0-11e8-b2bb-ac1f6b6435d0_red.png
#   inflating: train/fffe0ffe-bbc0-11e8-b2bb-ac1f6b6435d0_yellow.png

# %%
# !pip install pytorch-ignite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-ignite
#   Downloading pytorch_ignite-0.4.10-py3-none-any.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.1/264.1 KB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from pytorch-ignite) (21.3)
# Requirement already satisfied: torch<2,>=1.3 in /usr/local/lib/python3.8/dist-packages (from pytorch-ignite) (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch<2,>=1.3->pytorch-ignite) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->pytorch-ignite) (3.0.9)
# Installing collected packages: pytorch-ignite
# Successfully installed pytorch-ignite-0.4.10

# %%
# !pip install ignite.metrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement ignite.metrics (from versions: none)
# ERROR: No matching distribution found for ignite.metrics

# %%
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import Sampler
import torch
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
import pathlib
import torchvision.transforms as transforms
import torch
import PIL
from sklearn.model_selection import train_test_split

import sys
import pandas as pd
# from neptune import Context
from sklearn.metrics import f1_score
import torch.nn as nn
import torchvision.transforms as transforms
from torch import optim, save
from torch.utils.data import DataLoader
from torchvision.models import resnet50


from ignite.engine import Events
from ignite.engine import create_supervised_evaluator, create_supervised_trainer
from ignite.metrics import Accuracy, Recall, Precision
from ignite.metrics import Loss
import numpy as np
RANDOM_SEED = 666

LABEL_MAP = {
0: "Nucleoplasm" ,
1: "Nuclear membrane"   ,
2: "Nucleoli"   ,
3: "Nucleoli fibrillar center",   
4: "Nuclear speckles"   ,
5: "Nuclear bodies"   ,
6: "Endoplasmic reticulum"   ,
7: "Golgi apparatus"  ,
8: "Peroxisomes"   ,
9:  "Endosomes"   ,
10: "Lysosomes"   ,
11: "Intermediate filaments"  , 
12: "Actin filaments"   ,
13: "Focal adhesion sites"  ,
14: "Microtubules"   ,
15: "Microtubule ends"   ,
16: "Cytokinetic bridge"   ,
17: "Mitotic spindle"  ,
18: "Microtubule organizing center",  
19: "Centrosome",
20: "Lipid droplets"   ,
21: "Plasma membrane"  ,
22: "Cell junctions"   ,
23: "Mitochondria"   ,
24: "Aggresome"   ,
25: "Cytosol" ,
26: "Cytoplasmic bodies",
27: "Rods & rings"}





class MultiBandMultiLabelDataset(Dataset):
  BANDS_NAMES = ['_red.png','_green.png','_blue.png','_yellow.png']
    
  def __len__(self):
        return len(self.images_df)
    
  def __init__(self, images_df, 
                 base_path, 
                 image_transform, 
                 augmentator=None,
                 train_mode=True    
                ):
        if not isinstance(base_path, pathlib.Path):
            base_path = pathlib.Path(base_path)
            
        self.images_df = images_df.copy()
        self.image_transform = image_transform
        self.augmentator = augmentator
        self.images_df.Id = self.images_df.Id.apply(lambda x: base_path / x)
        self.mlb = MultiLabelBinarizer(classes=list(LABEL_MAP.keys()))
        self.train_mode = train_mode


  def __getitem__(self, index):
          y = None
          X = self._load_multiband_image(index)
          if self.train_mode:
              y = self._load_multilabel_target(index)
          
          # augmentator can be for instance imgaug augmentation object
          if self.augmentator is not None:
              X = self.augmentator(X)
              
          X = self.image_transform(X)
              
          return X, y 

  def _load_multiband_image(self, index):
        row = self.images_df.iloc[index]
        image_bands = []
        for band_name in self.BANDS_NAMES:
            p = str(row.Id.absolute()) + band_name
            pil_channel = PIL.Image.open(p)
            image_bands.append(pil_channel)
            
        # lets pretend its a RBGA image to support 4 channels
        band4image = PIL.Image.merge('RGBA', bands=image_bands)
        return band4image
    
    
  def _load_multilabel_target(self, index):
        return list(map(int, self.images_df.iloc[index].Target.split(' ')))


  def collate_func(self, batch):
        labels = None
        images = [x[0] for x in batch]
        
        if self.train_mode:
            labels = [x[1] for x in batch]
            labels_one_hot  = self.mlb.fit_transform(labels)
            labels = torch.FloatTensor(labels_one_hot)
            
        
        return torch.stack(images)[:,:4,:,:], labels

  def get_model(n_classes, image_channels=4):
    model = resnet50(pretrained=False)
    for p in model.parameters():
        p.requires_grad = True
    inft = model.fc.in_features
    model.fc = nn.Linear(in_features=inft, out_features=n_classes)
    model.avgpool = nn.AdaptiveAvgPool2d(1)
    model.conv1 = nn.Conv2d(image_channels, 64, kernel_size=7, stride=2, padding=3,
                               bias=False)
    
    return model  


  def train(trainer, train_loader, test_loader, checkpoint_path='bestmodel_{}_{}.torch', epochs=1):
    @trainer.on(Events.ITERATION_COMPLETED)
    def log_training_loss(engine):
        iter = (engine.state.iteration - 1) % len(train_loader) + 1
#         ctx.channel_send('loss', engine.state.output)
        if iter % 10 == 0:
            print("Epoch[{}] Iteration[{}/{}] Loss: {:.2f}"
                  "".format(engine.state.epoch, iter, len(train_loader), engine.state.output))

    @trainer.on(Events.EPOCH_COMPLETED)
    def log_training_results(engine):
        evaluator.run(test_loader)
        metrics = evaluator.state.metrics
        avg_nll = metrics['loss']
        print("Training Results - Epoch: {}  Avg loss: {:.2f}"
              .format(engine.state.epoch, avg_nll))
        save(model, checkpoint_path.format(engine.state.epoch, avg_nll))
    trainer.run(train_loader, max_epochs=epochs)
    
    return model 
    


  # Eval
  def evaluate(model, test_loader, threshold=0.2):
      all_preds = []
      true = []
      model.eval()
      for b in test_loader:
          X, y = b
          if torch.cuda.is_available():
              X, y = X.cuda(), y.cuda()
          pred = model(X)
          all_preds.append(pred.sigmoid().cpu().data.numpy())
          true.append(y.cpu().data.numpy())
          
          
      P = np.concatenate(all_preds)
      R = np.concatenate(true)
      
      f1 = f1_score(P>threshold, R, average='macro')
      print(f1)
      return f1


  ## Submission
  def predict_submission(model, submission_load):
      all_preds = []
      model.eval()
      for i, b in enumerate(submission_load):
          if i % 100: print('processing batch {}/{}'.format(i, len(submission_load)))
          X, _ = b
          if torch.cuda.is_available():
              X = X.cuda()
          pred = model(X)
          all_preds.append(pred.sigmoid().cpu().data.numpy())
      return np.concatenate(all_preds)


def make_submission_file(sample_submission_df, predictions):
    submissions = []
    for row in predictions:
        subrow = ' '.join(list([str(i) for i in np.nonzero(row)[0]]))
        submissions.append(subrow)
    
    sample_submission_df['Predicted'] = submissions
    sample_submission_df.to_csv('submission.csv', index=None)
    
    return sample_submission_df

    
PATH_TO_IMAGES = '../train/'
PATH_TO_TEST_IMAGES = '../test/'
PATH_TO_META = './train.csv'
SAMPLE_SUBMI = './sample_submission.csv'

# %%
# Prepare dataframe files

SEED = 666
DEV_MODE = True
    
df = pd.read_csv(PATH_TO_META)
df_train, df_test  = train_test_split(df, test_size=0.2, random_state=SEED)
df_submission = pd.read_csv(SAMPLE_SUBMI)

if DEV_MODE:
    df_train = df_train[:200]
    df_test = df_test[:50]
    df_submission = df_submission[:50]

image_transform = transforms.Compose([
            transforms.Resize(32),
            transforms.ToTensor(),
    
        ])

# Prepare datasets and loaders
   
gtrain = MultiBandMultiLabelDataset(df_train, base_path=PATH_TO_IMAGES, image_transform=image_transform)
gtest = MultiBandMultiLabelDataset(df_test, base_path=PATH_TO_IMAGES, image_transform=image_transform)
gsub = MultiBandMultiLabelDataset(df_submission, base_path=PATH_TO_TEST_IMAGES, train_mode=False, image_transform=image_transform)

train_load = DataLoader(gtrain, collate_fn=gtrain.collate_func, batch_size=16, num_workers=6)
test_load = DataLoader(gtest, collate_fn=gtest.collate_func, batch_size=16, num_workers=6)
submission_load = DataLoader(gsub, collate_fn=gsub.collate_func, batch_size=16, num_workers=6)


# Prepare model 

model = get_model(28,4)
device='cpu'
criterion = nn.BCEWithLogitsLoss()
if torch.cuda.is_available():
    criterion = criterion.cuda()
evaluator = create_supervised_evaluator(model,
                                            device=device,
                                            metrics={'loss': Loss(criterion)
                                                    })
optimizer = optim.Adam(filter(lambda p: p.requires_grad,model.parameters()), lr=0.00005)
trainer = create_supervised_trainer(model, optimizer, criterion, device=device)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a9f653e2bc5d> in <module>
#      32 # Prepare model
#      33
# ---> 34 model = get_model(28,4)
#      35 device='cpu'
#      36 criterion = nn.BCEWithLogitsLoss()
#
# NameError: name 'get_model' is not defined

# %%
# !ls
# Out:
# human-protein-atlas-image-classification.zip  kaggle.json  sample_data

# %% [markdown]
# **TRAIN**

# %%
# train the model
model = train(trainer, train_load, test_load, epochs=1)

# %% [markdown]
# **EVAL**

# %%
# evaluate on testing data and calculate F1-macro
res = evaluate(model, test_load, threshold=0.2)
print(res)

# %% [markdown]
# **SUBMISSION**

# %%
submission_predictions =predict_submission(model, submission_load)

# %%
# prepare the submission file and 
THRESHOLD = 0.2
p = submission_predictions>THRESHOLD

submission_file = make_submission_file(sample_submission_df=df_submission,
                     predictions=p)

# %%
submission_file.head()
